# %% [markdown]
# ### Loading the preprocessed data

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ### Data

# %%
npz = np.load('Audiobooks_data_train.npz')

train_inputs = npz['inputs'].astype(np.float64)
train_targets = npz['targets'].astype(np.int64)


npz = np.load('Audiobooks_data_validation.npz')

validation_inputs = npz['inputs'].astype(np.float64)
validation_targets = npz['targets'].astype(np.int64)

npz = np.load('Audiobooks_data_test.npz')

test_inputs = npz['inputs'].astype(np.float64)
test_targets = npz['targets'].astype(np.int64)

# %% [markdown]
# ### Creating the model

# %%
input_size = 10 # 10 predictors
output_size = 2 # 2 outputs
hidden_layer_size = 50

model = tf.keras.Sequential([
                                tf.keras.layers.Dense(hidden_layer_size, activation='relu'),    #Input layer tp hidden layer 1
                                tf.keras.layers.Dense(hidden_layer_size, activation='relu'),    #Hidden layer 1 to hidden layer 2
                                tf.keras.layers.Dense(output_size, activation='softmax'),    #Hidden layer 2 to Output layer 
                            ])

model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

BATCH_SIZE = 100
MAX_EPOCHS = 100

model.fit(train_inputs,
          train_targets,
          batch_size = BATCH_SIZE,
          epochs = MAX_EPOCHS,
          validation_data = (validation_inputs, validation_targets),
          verbose = 2)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 1s 4ms/step - loss: 0.5342 - accuracy: 0.7427 - val_loss: 0.4428 - val_accuracy: 0.7875
# Epoch 2/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.4412 - accuracy: 0.7756 - val_loss: 0.3945 - val_accuracy: 0.7942
# Epoch 3/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.4099 - accuracy: 0.7849 - val_loss: 0.3720 - val_accuracy: 0.8188
# Epoch 4/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3918 - accuracy: 0.8008 - val_loss: 0.3647 - val_accuracy: 0.8210
# Epoch 5/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3835 - accuracy: 0.7972 - val_loss: 0.3540 - val_accuracy: 0.8188
# Epoch 6/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3727 - accuracy: 0.8050 - val_loss: 0.3447 - val_accuracy: 0.8166
# Epoch 7/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3654 - accuracy: 0.8075 - val_loss: 0.3381 - val_accuracy: 0.8322
# Epoch 8/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3631 - accuracy: 0.8089 - val_loss: 0.3356 - val_accuracy: 0.8322
# Epoch 9/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3576 - accuracy: 0.8136 - val_loss: 0.3331 - val_accuracy: 0.8300
# Epoch 10/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3565 - accuracy: 0.8145 - val_loss: 0.3312 - val_accuracy: 0.8367
# Epoch 11/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3553 - accuracy: 0.8145 - val_loss: 0.3270 - val_accuracy: 0.8322
# Epoch 12/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3529 - accuracy: 0.8206 - val_loss: 0.3320 - val_accuracy: 0.8233
# Epoch 13/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8178 - val_loss: 0.3263 - val_accuracy: 0.8367
# Epoch 14/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3478 - accuracy: 0.8209 - val_loss: 0.3247 - val_accuracy: 0.8322
# Epoch 15/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3458 - accuracy: 0.8229 - val_loss: 0.3229 - val_accuracy: 0.8412
# Epoch 16/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3430 - accuracy: 0.8209 - val_loss: 0.3223 - val_accuracy: 0.8300
# Epoch 17/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3449 - accuracy: 0.8201 - val_loss: 0.3201 - val_accuracy: 0.8300
# Epoch 18/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3414 - accuracy: 0.8215 - val_loss: 0.3280 - val_accuracy: 0.8322
# Epoch 19/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3388 - accuracy: 0.8217 - val_loss: 0.3199 - val_accuracy: 0.8345
# Epoch 20/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3434 - accuracy: 0.8170 - val_loss: 0.3239 - val_accuracy: 0.8412
# Epoch 21/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3430 - accuracy: 0.8237 - val_loss: 0.3213 - val_accuracy: 0.8412
# Epoch 22/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3389 - accuracy: 0.8206 - val_loss: 0.3162 - val_accuracy: 0.8345
# Epoch 23/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3386 - accuracy: 0.8234 - val_loss: 0.3185 - val_accuracy: 0.8389
# Epoch 24/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3397 - accuracy: 0.8217 - val_loss: 0.3181 - val_accuracy: 0.8300
# Epoch 25/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3420 - accuracy: 0.8164 - val_loss: 0.3166 - val_accuracy: 0.8345
# Epoch 26/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3365 - accuracy: 0.8220 - val_loss: 0.3157 - val_accuracy: 0.8322
# Epoch 27/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3365 - accuracy: 0.8243 - val_loss: 0.3258 - val_accuracy: 0.8389
# Epoch 28/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3367 - accuracy: 0.8251 - val_loss: 0.3179 - val_accuracy: 0.8322
# Epoch 29/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3363 - accuracy: 0.8254 - val_loss: 0.3145 - val_accuracy: 0.8367
# Epoch 30/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3354 - accuracy: 0.8229 - val_loss: 0.3151 - val_accuracy: 0.8322
# Epoch 31/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3336 - accuracy: 0.8248 - val_loss: 0.3164 - val_accuracy: 0.8367
# Epoch 32/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8237 - val_loss: 0.3176 - val_accuracy: 0.8345
# Epoch 33/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3352 - accuracy: 0.8209 - val_loss: 0.3144 - val_accuracy: 0.8322
# Epoch 34/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3355 - accuracy: 0.8245 - val_loss: 0.3154 - val_accuracy: 0.8345
# Epoch 35/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8243 - val_loss: 0.3158 - val_accuracy: 0.8345
# Epoch 36/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3318 - accuracy: 0.8268 - val_loss: 0.3121 - val_accuracy: 0.8345
# Epoch 37/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3324 - accuracy: 0.8254 - val_loss: 0.3153 - val_accuracy: 0.8345
# Epoch 38/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3317 - accuracy: 0.8273 - val_loss: 0.3228 - val_accuracy: 0.8345
# Epoch 39/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3335 - accuracy: 0.8279 - val_loss: 0.3168 - val_accuracy: 0.8434
# Epoch 40/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3317 - accuracy: 0.8223 - val_loss: 0.3166 - val_accuracy: 0.8345
# Epoch 41/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3302 - accuracy: 0.8256 - val_loss: 0.3142 - val_accuracy: 0.8412
# Epoch 42/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3333 - accuracy: 0.8217 - val_loss: 0.3152 - val_accuracy: 0.8322
# Epoch 43/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3342 - accuracy: 0.8270 - val_loss: 0.3136 - val_accuracy: 0.8255
# Epoch 44/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8203 - val_loss: 0.3211 - val_accuracy: 0.8255
# Epoch 45/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8234 - val_loss: 0.3131 - val_accuracy: 0.8322
# Epoch 46/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3310 - accuracy: 0.8245 - val_loss: 0.3127 - val_accuracy: 0.8345
# Epoch 47/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3302 - accuracy: 0.8290 - val_loss: 0.3171 - val_accuracy: 0.8300
# Epoch 48/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3267 - accuracy: 0.8284 - val_loss: 0.3162 - val_accuracy: 0.8412
# Epoch 49/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3281 - accuracy: 0.8273 - val_loss: 0.3177 - val_accuracy: 0.8367
# Epoch 50/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 0.8265 - val_loss: 0.3190 - val_accuracy: 0.8389
# Epoch 51/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3323 - accuracy: 0.8259 - val_loss: 0.3137 - val_accuracy: 0.8277
# Epoch 52/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3332 - accuracy: 0.8262 - val_loss: 0.3142 - val_accuracy: 0.8345
# Epoch 53/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3299 - accuracy: 0.8259 - val_loss: 0.3133 - val_accuracy: 0.8300
# Epoch 54/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3280 - accuracy: 0.8304 - val_loss: 0.3125 - val_accuracy: 0.8412
# Epoch 55/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3294 - accuracy: 0.8315 - val_loss: 0.3121 - val_accuracy: 0.8322
# Epoch 56/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3295 - accuracy: 0.8284 - val_loss: 0.3148 - val_accuracy: 0.8345
# Epoch 57/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3312 - accuracy: 0.8245 - val_loss: 0.3208 - val_accuracy: 0.8255
# Epoch 58/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3269 - accuracy: 0.8276 - val_loss: 0.3125 - val_accuracy: 0.8322
# Epoch 59/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3270 - accuracy: 0.8256 - val_loss: 0.3110 - val_accuracy: 0.8345
# Epoch 60/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3275 - accuracy: 0.8265 - val_loss: 0.3108 - val_accuracy: 0.8345
# Epoch 61/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3265 - accuracy: 0.8293 - val_loss: 0.3154 - val_accuracy: 0.8345
# Epoch 62/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3310 - accuracy: 0.8245 - val_loss: 0.3096 - val_accuracy: 0.8367
# Epoch 63/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3269 - accuracy: 0.8262 - val_loss: 0.3202 - val_accuracy: 0.8367
# Epoch 64/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3316 - accuracy: 0.8262 - val_loss: 0.3119 - val_accuracy: 0.8322
# Epoch 65/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.8282 - val_loss: 0.3138 - val_accuracy: 0.8322
# Epoch 66/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3256 - accuracy: 0.8307 - val_loss: 0.3108 - val_accuracy: 0.8300
# Epoch 67/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3260 - accuracy: 0.8256 - val_loss: 0.3103 - val_accuracy: 0.8389
# Epoch 68/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3257 - accuracy: 0.8326 - val_loss: 0.3179 - val_accuracy: 0.8367
# Epoch 69/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3296 - accuracy: 0.8251 - val_loss: 0.3111 - val_accuracy: 0.8345
# Epoch 70/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3278 - accuracy: 0.8276 - val_loss: 0.3163 - val_accuracy: 0.8367
# Epoch 71/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3301 - accuracy: 0.8268 - val_loss: 0.3110 - val_accuracy: 0.8345
# Epoch 72/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3267 - accuracy: 0.8287 - val_loss: 0.3124 - val_accuracy: 0.8345
# Epoch 73/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3252 - accuracy: 0.8324 - val_loss: 0.3123 - val_accuracy: 0.8367
# Epoch 74/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3275 - accuracy: 0.8254 - val_loss: 0.3163 - val_accuracy: 0.8300
# Epoch 75/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3267 - accuracy: 0.8324 - val_loss: 0.3185 - val_accuracy: 0.8300
# Epoch 76/100
# 36/36 [==============================] - 0s 1ms/step - loss: 0.3290 - accuracy: 0.8282 - val_loss: 0.3137 - val_accuracy: 0.8367
# Epoch 77/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3251 - accuracy: 0.8301 - val_loss: 0.3200 - val_accuracy: 0.8434
# Epoch 78/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3286 - accuracy: 0.8284 - val_loss: 0.3151 - val_accuracy: 0.8322
# Epoch 79/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 0.8310 - val_loss: 0.3083 - val_accuracy: 0.8389
# Epoch 80/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3263 - accuracy: 0.8296 - val_loss: 0.3181 - val_accuracy: 0.8367
# Epoch 81/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3269 - accuracy: 0.8318 - val_loss: 0.3111 - val_accuracy: 0.8322
# Epoch 82/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.3290 - accuracy: 0.8245 - val_loss: 0.3199 - val_accuracy: 0.8345
# Epoch 83/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.3233 - accuracy: 0.8357
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30480\422185197.py in <module>
#      18           batch_size = BATCH_SIZE,
#      19           epochs = MAX_EPOCHS,
# ---> 20           validation_data = (validation_inputs, validation_targets))
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1703                         use_multiprocessing=use_multiprocessing,
#    1704                         return_dict=True,
# -> 1705                         _use_cached_eval_dataset=True,
#    1706                     )
#    1707                     val_logs = {
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2030             self._test_counter.assign(0)
#    2031             callbacks.on_test_begin()
# -> 2032             for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2033                 self.reset_metrics()
#    2034                 with data_handler.catch_stop_iteration():
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\engine\data_adapter.py in enumerate_epochs(self)
#    1302         """Yields `(epoch, tf.data.Iterator)`."""
#    1303         with self._truncate_execution_to_epoch():
# -> 1304             data_iterator = iter(self._dataset)
#    1305             for epoch in range(self._initial_epoch, self._epochs):
#    1306                 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\ops\dataset_ops.py in __iter__(self)
#     497     if context.executing_eagerly() or ops.inside_function():
#     498       with ops.colocate_with(self._variant_tensor):
# --> 499         return iterator_ops.OwnedIterator(self)
#     500     else:
#     501       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\ops\iterator_ops.py in __init__(self, dataset, components, element_spec)
#     701             "When `dataset` is provided, `element_spec` and `components` must "
#     702             "not be specified.")
# --> 703       self._create_iterator(dataset)
#     704
#     705     self._get_next_call_count = 0
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\ops\iterator_ops.py in _create_iterator(self, dataset)
#     740             self._flat_output_types)
#     741         self._iterator_resource.op.experimental_set_type(fulltype)
# --> 742       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     743
#     744   def __iter__(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\ops\gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3438     try:
#    3439       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 3440         _ctx, "MakeIterator", name, dataset, iterator)
#    3441       return _result
#    3442     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
